# %% [markdown]
# `Helsinki-NLP/opus_books` is a collection of copyright free books aligned by Andras Farkas. All texts are freely available for personal, educational and research use. Commercial use (e.g. reselling as parallel books) and mass redistribution without explicit permission are not granted.
#
# See more about the dataset: https://huggingface.co/datasets/Helsinki-NLP/opus_books
#
# In this section, we will use this dataset to train a seq2seq translation model.

# %% [markdown]
# We use the English - French as the example

# %%
from datasets import load_dataset

books = load_dataset("opus_books", "en-fr")

# %%
#resource limited, we only train on a small subset of dataset (but you can train on the full one if you want)
books_small = books["train"].train_test_split(train_size=0.1, seed=42)

books = books_small["train"].train_test_split(test_size=0.1, seed=42)

print(books)
print(books["train"][0])
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['id', 'translation'],
#         num_rows: 11437
#     })
#     test: Dataset({
#         features: ['id', 'translation'],
#         num_rows: 1271
#     })
# })
# {'id': '69877', 'translation': {'en': 'The worldly reason, however, assigned for this singular proceeding, was one which I did not feel at liberty to dispute.', 'fr': "La raison humaine qu'il donnait de cette singulière manière d'agir était une de ces raisons que je ne me sentais pas le droit de contredire."}}

# %% [markdown]
# The main purpose of this practical session is to get familiar with how the relevant libraries and models run. Considering possible resource limitations, we are not using large datasets or big models here: this is intended purely as usage guidance, and model performance is not our primary focus. You are welcome to explore longer training.

# %% [markdown]
# # Task1: Fine-tune a pre-trained seq2seq model using the Transformers library

# %%
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM
from transformers import DataCollatorForSeq2Seq, Seq2SeqTrainer, Seq2SeqTrainingArguments

model_checkpoint = "Helsinki-NLP/opus-mt-en-fr"
tokenizer = AutoTokenizer.from_pretrained(model_checkpoint)
model = AutoModelForSeq2SeqLM.from_pretrained(model_checkpoint)
# Out:
# c:\Users\naja\anaconda3\Lib\site-packages\transformers\models\marian\tokenization_marian.py:175: UserWarning: Recommended: pip install sacremoses.
#   warnings.warn("Recommended: pip install sacremoses.")

# %% [markdown]
# ### Preprocessing Function
#
# The `preprocess_function` prepares translation data for model training:
#
# - Extracts source and target sentences from `examples["translation"]`.
# - Tokenizes the source text into `input_ids` and `attention_mask`.
# - Tokenizes the target text as labels.
# - Returns a dictionary with `input_ids`, `attention_mask`, and `labels` for the model.

# %%
source_lang = "en"
target_lang = "fr"
max_length = 128

def preprocess_function(examples):
    # Extract source and target sentences
    inputs = [ex[source_lang] for ex in examples["translation"]]
    targets = [ex[target_lang] for ex in examples["translation"]]

    # Tokenize source sentences
    model_inputs = tokenizer(inputs, max_length=max_length, truncation=True)

    # Tokenize target sentences as labels
    with tokenizer.as_target_tokenizer():
        labels = tokenizer(targets, max_length=max_length, truncation=True)
    model_inputs["labels"] = labels["input_ids"]
    return model_inputs

tokenized_datasets = books.map(preprocess_function, batched=True)
# Out:
# Map:   0%|          | 0/11437 [00:00<?, ? examples/s]
# c:\Users\naja\anaconda3\Lib\site-packages\transformers\tokenization_utils_base.py:4007: UserWarning: `as_target_tokenizer` is deprecated and will be removed in v5 of Transformers. You can tokenize your labels by using the argument `text_target` of the regular `__call__` method (either in the same call as your input texts if you use the same keyword arguments, or in a separate call.
#   warnings.warn(
# Map:   0%|          | 0/1271 [00:00<?, ? examples/s]

# %%
# !pip install evaluate
# !pip install sacrebleu
# Out:
# Collecting evaluate
#   Downloading evaluate-0.4.6-py3-none-any.whl.metadata (9.5 kB)
# Requirement already satisfied: datasets>=2.0.0 in c:\users\naja\anaconda3\lib\site-packages (from evaluate) (4.0.0)
# Requirement already satisfied: numpy>=1.17 in c:\users\naja\anaconda3\lib\site-packages (from evaluate) (1.26.4)
# Requirement already satisfied: dill in c:\users\naja\anaconda3\lib\site-packages (from evaluate) (0.3.8)
# Requirement already satisfied: pandas in c:\users\naja\anaconda3\lib\site-packages (from evaluate) (2.2.2)
# Requirement already satisfied: requests>=2.19.0 in c:\users\naja\anaconda3\lib\site-packages (from evaluate) (2.32.3)
# Requirement already satisfied: tqdm>=4.62.1 in c:\users\naja\anaconda3\lib\site-packages (from evaluate) (4.66.5)
# Requirement already satisfied: xxhash in c:\users\naja\anaconda3\lib\site-packages (from evaluate) (3.5.0)
# Requirement already satisfied: multiprocess in c:\users\naja\anaconda3\lib\site-packages (from evaluate) (0.70.16)
# Requirement already satisfied: fsspec>=2021.05.0 in c:\users\naja\anaconda3\lib\site-packages (from fsspec[http]>=2021.05.0->evaluate) (2024.6.1)
# Requirement already satisfied: huggingface-hub>=0.7.0 in c:\users\naja\anaconda3\lib\site-packages (from evaluate) (0.34.4)
# Requirement already satisfied: packaging in c:\users\naja\anaconda3\lib\site-packages (from evaluate) (24.1)
# Requirement already satisfied: filelock in c:\users\naja\anaconda3\lib\site-packages (from datasets>=2.0.0->evaluate) (3.13.1)
# Requirement already satisfied: pyarrow>=15.0.0 in c:\users\naja\anaconda3\lib\site-packages (from datasets>=2.0.0->evaluate) (18.0.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\naja\anaconda3\lib\site-packages (from datasets>=2.0.0->evaluate) (6.0.1)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in c:\users\naja\anaconda3\lib\site-packages (from fsspec[http]>=2021.05.0->evaluate) (3.10.5)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\naja\anaconda3\lib\site-packages (from huggingface-hub>=0.7.0->evaluate) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\naja\anaconda3\lib\site-packages (from requests>=2.19.0->evaluate) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\naja\anaconda3\lib\site-packages (from requests>=2.19.0->evaluate) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\naja\anaconda3\lib\site-packages (from requests>=2.19.0->evaluate) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\naja\anaconda3\lib\site-packages (from requests>=2.19.0->evaluate) (2025.8.3)
# Requirement already satisfied: colorama in c:\users\naja\anaconda3\lib\site-packages (from tqdm>=4.62.1->evaluate) (0.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\naja\anaconda3\lib\site-packages (from pandas->evaluate) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\naja\anaconda3\lib\site-packages (from pandas->evaluate) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\naja\anaconda3\lib\site-packages (from pandas->evaluate) (2023.3)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\naja\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\naja\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\naja\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\naja\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\naja\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\naja\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (1.11.0)
# Requirement already satisfied: six>=1.5 in c:\users\naja\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas->evaluate) (1.16.0)
# Downloading evaluate-0.4.6-py3-none-any.whl (84 kB)
# Installing collected packages: evaluate
# Successfully installed evaluate-0.4.6
# Collecting sacrebleu
#   Downloading sacrebleu-2.5.1-py3-none-any.whl.metadata (51 kB)
# Collecting portalocker (from sacrebleu)
#   Downloading portalocker-3.2.0-py3-none-any.whl.metadata (8.7 kB)
# Requirement already satisfied: regex in c:\users\naja\anaconda3\lib\site-packages (from sacrebleu) (2024.9.11)
# Requirement already satisfied: tabulate>=0.8.9 in c:\users\naja\anaconda3\lib\site-packages (from sacrebleu) (0.9.0)
# Requirement already satisfied: numpy>=1.17 in c:\users\naja\anaconda3\lib\site-packages (from sacrebleu) (1.26.4)
# Requirement already satisfied: colorama in c:\users\naja\anaconda3\lib\site-packages (from sacrebleu) (0.4.6)
# Requirement already satisfied: lxml in c:\users\naja\anaconda3\lib\site-packages (from sacrebleu) (5.2.1)
# Requirement already satisfied: pywin32>=226 in c:\users\naja\anaconda3\lib\site-packages (from portalocker->sacrebleu) (305.1)
# Downloading sacrebleu-2.5.1-py3-none-any.whl (104 kB)
# Downloading portalocker-3.2.0-py3-none-any.whl (22 kB)
# Installing collected packages: portalocker, sacrebleu
# Successfully installed portalocker-3.2.0 sacrebleu-2.5.1

# %% [markdown]
# ### Evaluation Function
#
# The code defines evaluation with the **sacreBLEU** metric:
#
# - `postprocess_text`: cleans predictions and labels by stripping spaces and formatting labels.
# - `compute_metrics`:
#   - Decodes model predictions and labels.
#   - Postprocesses them for evaluation.
#   - Computes BLEU score using `sacrebleu`.
#   - Returns the BLEU score as a dictionary.

# %%
import evaluate

# Load the sacreBLEU metric
metric = evaluate.load("sacrebleu")

def postprocess_text(preds, labels):
    preds = [p.strip() for p in preds]
    labels = [[l.strip()] for l in labels]
    return preds, labels

def compute_metrics(eval_preds):
    preds, labels = eval_preds

    # Decode token IDs to strings
    decoded_preds = tokenizer.batch_decode(preds, skip_special_tokens=True)
    decoded_labels = tokenizer.batch_decode(labels, skip_special_tokens=True)

    # Postprocess
    decoded_preds, decoded_labels = postprocess_text(decoded_preds, decoded_labels)

    # Compute BLEU
    result = metric.compute(predictions=decoded_preds, references=decoded_labels)
    
    return {"bleu": result["score"]}

# %% [markdown]
# ### Training with Seq2SeqTrainer
#
# This task sets up and runs training for a sequence-to-sequence model:
#
# - **Seq2SeqTrainingArguments**: defines training parameters such as batch size, epochs, logging.
# - **DataCollatorForSeq2Seq**: prepares batches with dynamic padding for seq2seq training.
# - **Seq2SeqTrainer**: combines the model, datasets, tokenizer, collator, and evaluation metric.
# - **trainer.train()**: starts the training process.

# %%
import torch
from transformers import DataCollatorForSeq2Seq, Seq2SeqTrainingArguments, Seq2SeqTrainer

# Define training arguments
args = Seq2SeqTrainingArguments(
    "en-fr-demo",
      per_device_train_batch_size=8,
      per_device_eval_batch_size=1,
      predict_with_generate=True,
      num_train_epochs=1,
      save_total_limit=1,
      report_to="none",
      logging_strategy="steps",
      logging_steps=50,
      fp16=torch.cuda.is_available(),
)

# Data collator with dynamic padding
data_collator = DataCollatorForSeq2Seq(tokenizer, model=model)

# Set up Trainer
trainer = Seq2SeqTrainer(
    model=model,
    args=args,
    train_dataset=tokenized_datasets["train"],
    eval_dataset=tokenized_datasets["test"],
    data_collator=data_collator,
    tokenizer=tokenizer,
    compute_metrics=compute_metrics
)

# Start training
trainer.train()
# Out:
# C:\Users\naja\AppData\Local\Temp\ipykernel_18292\3440609649.py:22: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Seq2SeqTrainer.__init__`. Use `processing_class` instead.
#   trainer = Seq2SeqTrainer(
# c:\Users\naja\anaconda3\Lib\site-packages\torch\utils\data\dataloader.py:666: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
#     <div>
#
#       <progress value='6' max='1430' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [   6/1430 00:06 < 38:01, 0.62 it/s, Epoch 0.00/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 33
#      22 trainer = Seq2SeqTrainer(
#      23     model=model,
#      24     args=args,
#    (...)
#      29     compute_metrics=compute_metrics
#      30 )
#      32 # Start training
# ---> 33 trainer.train()
#
# File c:\Users\naja\anaconda3\Lib\site-packages\transformers\trainer.py:2328, in Trainer.train(self, resume_from_checkpoint, trial, ignore_keys_for_eval, **kwargs)
#    2326         hf_hub_utils.enable_progress_bars()
#    2327 else:
# -> 2328     return inner_training_loop(
#    2329         args=args,
#    2330         resume_from_checkpoint=resume_from_checkpoint,
#    2331         trial=trial,
#    2332         ignore_keys_for_eval=ignore_keys_for_eval,
#    2333     )
#
# File c:\Users\naja\anaconda3\Lib\site-packages\transformers\trainer.py:2672, in Trainer._inner_training_loop(self, batch_size, args, resume_from_checkpoint, trial, ignore_keys_for_eval)
#    2665 context = (
#    2666     functools.partial(self.accelerator.no_sync, model=model)
#    2667     if i != len(batch_samples) - 1
#    2668     and self.accelerator.distributed_type != DistributedType.DEEPSPEED
#    2669     else contextlib.nullcontext
#    2670 )
#    2671 with context():
# -> 2672     tr_loss_step = self.training_step(model, inputs, num_items_in_batch)
#    2674 if (
#    2675     args.logging_nan_inf_filter
#    2676     and not is_torch_xla_available()
#    2677     and (torch.isnan(tr_loss_step) or torch.isinf(tr_loss_step))
#    2678 ):
#    2679     # if loss is nan or inf simply add the average of previous logged losses
#    2680     tr_loss = tr_loss + tr_loss / (1 + self.state.global_step - self._globalstep_last_logged)
#
# File c:\Users\naja\anaconda3\Lib\site-packages\transformers\trainer.py:4009, in Trainer.training_step(self, model, inputs, num_items_in_batch)
#    4006     return loss_mb.reduce_mean().detach().to(self.args.device)
#    4008 with self.compute_loss_context_manager():
# -> 4009     loss = self.compute_loss(model, inputs, num_items_in_batch=num_items_in_batch)
#    4011 del inputs
#    4012 if (
#    4013     self.args.torch_empty_cache_steps is not None
#    4014     and self.state.global_step % self.args.torch_empty_cache_steps == 0
#    4015 ):
#
# File c:\Users\naja\anaconda3\Lib\site-packages\transformers\trainer.py:4099, in Trainer.compute_loss(self, model, inputs, return_outputs, num_items_in_batch)
#    4097         kwargs["num_items_in_batch"] = num_items_in_batch
#    4098     inputs = {**inputs, **kwargs}
# -> 4099 outputs = model(**inputs)
#    4100 # Save past state if it exists
#    4101 # TODO: this needs to be fixed and made cleaner later.
#    4102 if self.args.past_index >= 0:
#
# File c:\Users\naja\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File c:\Users\naja\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File c:\Users\naja\anaconda3\Lib\site-packages\transformers\models\marian\modeling_marian.py:1524, in MarianMTModel.forward(self, input_ids, attention_mask, decoder_input_ids, decoder_attention_mask, head_mask, decoder_head_mask, cross_attn_head_mask, encoder_outputs, past_key_values, inputs_embeds, decoder_inputs_embeds, labels, use_cache, output_attentions, output_hidden_states, return_dict, cache_position)
#    1519     if decoder_input_ids is None and decoder_inputs_embeds is None:
#    1520         decoder_input_ids = shift_tokens_right(
#    1521             labels, self.config.pad_token_id, self.config.decoder_start_token_id
#    1522         )
# -> 1524 outputs = self.model(
#    1525     input_ids,
#    1526     attention_mask=attention_mask,
#    1527     decoder_input_ids=decoder_input_ids,
#    1528     encoder_outputs=encoder_outputs,
#    1529     decoder_attention_mask=decoder_attention_mask,
#    1530     head_mask=head_mask,
#    1531     decoder_head_mask=decoder_head_mask,
#    1532     cross_attn_head_mask=cross_attn_head_mask,
#    1533     past_key_values=past_key_values,
#    1534     inputs_embeds=inputs_embeds,
#    1535     decoder_inputs_embeds=decoder_inputs_embeds,
#    1536     use_cache=use_cache,
#    1537     output_attentions=output_attentions,
#    1538     output_hidden_states=output_hidden_states,
#    1539     return_dict=return_dict,
#    1540     cache_position=cache_position,
#    1541 )
#    1542 lm_logits = self.lm_head(outputs[0]) + self.final_logits_bias
#    1544 masked_lm_loss = None
#
# File c:\Users\naja\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File c:\Users\naja\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File c:\Users\naja\anaconda3\Lib\site-packages\transformers\models\marian\modeling_marian.py:1280, in MarianModel.forward(self, input_ids, attention_mask, decoder_input_ids, decoder_attention_mask, head_mask, decoder_head_mask, cross_attn_head_mask, encoder_outputs, past_key_values, inputs_embeds, decoder_inputs_embeds, use_cache, output_attentions, output_hidden_states, return_dict, cache_position)
#    1273     encoder_outputs = BaseModelOutput(
#    1274         last_hidden_state=encoder_outputs[0],
#    1275         hidden_states=encoder_outputs[1] if len(encoder_outputs) > 1 else None,
#    1276         attentions=encoder_outputs[2] if len(encoder_outputs) > 2 else None,
#    1277     )
#    1279 # decoder outputs consists of (dec_features, past_key_values, dec_hidden, dec_attn)
# -> 1280 decoder_outputs = self.decoder(
#    1281     input_ids=decoder_input_ids,
#    1282     attention_mask=decoder_attention_mask,
#    1283     encoder_hidden_states=encoder_outputs[0],
#    1284     encoder_attention_mask=attention_mask,
#    1285     head_mask=decoder_head_mask,
#    1286     cross_attn_head_mask=cross_attn_head_mask,
#    1287     past_key_values=past_key_values,
#    1288     inputs_embeds=decoder_inputs_embeds,
#    1289     use_cache=use_cache,
#    1290     output_attentions=output_attentions,
#    1291     output_hidden_states=output_hidden_states,
#    1292     return_dict=return_dict,
#    1293     cache_position=cache_position,
#    1294 )
#    1296 if not return_dict:
#    1297     return decoder_outputs + encoder_outputs
#
# File c:\Users\naja\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File c:\Users\naja\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File c:\Users\naja\anaconda3\Lib\site-packages\transformers\models\marian\modeling_marian.py:1071, in MarianDecoder.forward(self, input_ids, attention_mask, encoder_hidden_states, encoder_attention_mask, head_mask, cross_attn_head_mask, past_key_values, inputs_embeds, use_cache, output_attentions, output_hidden_states, return_dict, cache_position)
#    1068     if dropout_probability < self.layerdrop:
#    1069         continue
# -> 1071 layer_outputs = decoder_layer(
#    1072     hidden_states,
#    1073     causal_mask,
#    1074     encoder_hidden_states,  # as a positional argument for gradient checkpointing
#    1075     encoder_attention_mask=encoder_attention_mask,
#    1076     layer_head_mask=(head_mask[idx] if head_mask is not None else None),
#    1077     cross_attn_layer_head_mask=(cross_attn_head_mask[idx] if cross_attn_head_mask is not None else None),
#    1078     past_key_values=past_key_values,
#    1079     output_attentions=output_attentions,
#    1080     use_cache=use_cache,
#    1081     cache_position=cache_position,
#    1082 )
#    1083 hidden_states = layer_outputs[0]
#    1085 if output_attentions:
#
# File c:\Users\naja\anaconda3\Lib\site-packages\transformers\modeling_layers.py:94, in GradientCheckpointingLayer.__call__(self, *args, **kwargs)
#      91         logger.warning_once(message)
#      93     return self._gradient_checkpointing_func(partial(super().__call__, **kwargs), *args)
# ---> 94 return super().__call__(*args, **kwargs)
#
# File c:\Users\naja\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File c:\Users\naja\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File c:\Users\naja\anaconda3\Lib\site-packages\transformers\utils\deprecation.py:172, in deprecate_kwarg.<locals>.wrapper.<locals>.wrapped_func(*args, **kwargs)
#     168 elif minimum_action in (Action.NOTIFY, Action.NOTIFY_ALWAYS) and not is_torchdynamo_compiling():
#     169     # DeprecationWarning is ignored by default, so we use FutureWarning instead
#     170     warnings.warn(message, FutureWarning, stacklevel=2)
# --> 172 return func(*args, **kwargs)
#
# File c:\Users\naja\anaconda3\Lib\site-packages\transformers\models\marian\modeling_marian.py:418, in MarianDecoderLayer.forward(self, hidden_states, attention_mask, encoder_hidden_states, encoder_attention_mask, layer_head_mask, cross_attn_layer_head_mask, past_key_values, output_attentions, use_cache, cache_position)
#     415 residual = hidden_states
#     417 # Self Attention
# --> 418 hidden_states, self_attn_weights = self.self_attn(
#     419     hidden_states=hidden_states,
#     420     past_key_values=past_key_values,
#     421     attention_mask=attention_mask,
#     422     layer_head_mask=layer_head_mask,
#     423     output_attentions=output_attentions,
#     424     cache_position=cache_position,
#     425 )
#     426 hidden_states = nn.functional.dropout(hidden_states, p=self.dropout, training=self.training)
#     427 hidden_states = residual + hidden_states
#
# File c:\Users\naja\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File c:\Users\naja\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File c:\Users\naja\anaconda3\Lib\site-packages\transformers\utils\deprecation.py:172, in deprecate_kwarg.<locals>.wrapper.<locals>.wrapped_func(*args, **kwargs)
#     168 elif minimum_action in (Action.NOTIFY, Action.NOTIFY_ALWAYS) and not is_torchdynamo_compiling():
#     169     # DeprecationWarning is ignored by default, so we use FutureWarning instead
#     170     warnings.warn(message, FutureWarning, stacklevel=2)
# --> 172 return func(*args, **kwargs)
#
# File c:\Users\naja\anaconda3\Lib\site-packages\transformers\models\marian\modeling_marian.py:256, in MarianAttention.forward(self, hidden_states, key_value_states, past_key_values, attention_mask, layer_head_mask, output_attentions, cache_position, **kwargs)
#     253 if self.config._attn_implementation != "eager":
#     254     attention_interface = ALL_ATTENTION_FUNCTIONS[self.config._attn_implementation]
# --> 256 attn_output, attn_weights = attention_interface(
#     257     self,
#     258     query_states,
#     259     key_states,
#     260     value_states,
#     261     attention_mask,
#     262     dropout=0.0 if not self.training else self.dropout,
#     263     scaling=self.scaling,
#     264     output_attentions=output_attentions,
#     265     head_mask=layer_head_mask,
#     266     **kwargs,
#     267 )
#     269 attn_output = attn_output.reshape(bsz, tgt_len, -1).contiguous()
#     270 attn_output = self.out_proj(attn_output)
#
# File c:\Users\naja\anaconda3\Lib\site-packages\transformers\integrations\sdpa_attention.py:83, in sdpa_attention_forward(module, query, key, value, attention_mask, dropout, scaling, is_causal, **kwargs)
#      80 if torch.jit.is_tracing() and isinstance(is_causal, torch.Tensor):
#      81     is_causal = is_causal.item()
# ---> 83 attn_output = torch.nn.functional.scaled_dot_product_attention(
#      84     query,
#      85     key,
#      86     value,
#      87     attn_mask=attention_mask,
#      88     dropout_p=dropout,
#      89     scale=scaling,
#      90     is_causal=is_causal,
#      91     **sdpa_kwargs,
#      92 )
#      93 attn_output = attn_output.transpose(1, 2).contiguous()
#      95 return attn_output, None
#
# KeyboardInterrupt:

# %%
results = trainer.evaluate()
print(results)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 results = trainer.evaluate()
#       2 print(results)
#
# File c:\Users\naja\anaconda3\Lib\site-packages\transformers\trainer_seq2seq.py:191, in Seq2SeqTrainer.evaluate(self, eval_dataset, ignore_keys, metric_key_prefix, **gen_kwargs)
#     189 self.gather_function = self.accelerator.gather
#     190 self._gen_kwargs = gen_kwargs
# --> 191 return super().evaluate(eval_dataset, ignore_keys=ignore_keys, metric_key_prefix=metric_key_prefix)
#
# File c:\Users\naja\anaconda3\Lib\site-packages\transformers\trainer.py:4469, in Trainer.evaluate(self, eval_dataset, ignore_keys, metric_key_prefix)
#    4466 start_time = time.time()
#    4468 eval_loop = self.prediction_loop if self.args.use_legacy_prediction_loop else self.evaluation_loop
# -> 4469 output = eval_loop(
#    4470     eval_dataloader,
#    4471     description="Evaluation",
#    4472     # No point gathering the predictions if there are no metrics, otherwise we defer to
#    4473     # self.args.prediction_loss_only
#    4474     prediction_loss_only=True if self.compute_metrics is None else None,
#    4475     ignore_keys=ignore_keys,
#    4476     metric_key_prefix=metric_key_prefix,
#    4477 )
#    4479 total_batch_size = self.args.eval_batch_size * self.args.world_size
#    4480 if f"{metric_key_prefix}_jit_compilation_time" in output.metrics:
#
# File c:\Users\naja\anaconda3\Lib\site-packages\transformers\trainer.py:4665, in Trainer.evaluation_loop(self, dataloader, description, prediction_loss_only, ignore_keys, metric_key_prefix)
#    4662         batch_size = observed_batch_size
#    4664 # Prediction step
# -> 4665 losses, logits, labels = self.prediction_step(model, inputs, prediction_loss_only, ignore_keys=ignore_keys)
#    4666 main_input_name = getattr(self.model, "main_input_name", "input_ids")
#    4667 inputs_decode = (
#    4668     self._prepare_input(inputs[main_input_name]) if "inputs" in args.include_for_metrics else None
#    4669 )
#
# File c:\Users\naja\anaconda3\Lib\site-packages\transformers\trainer_seq2seq.py:327, in Seq2SeqTrainer.prediction_step(self, model, inputs, prediction_loss_only, ignore_keys, **gen_kwargs)
#     320 summon_full_params_context = (
#     321     FullyShardedDataParallel.summon_full_params(self.model)
#     322     if isinstance(self.model, FullyShardedDataParallel)
#     323     else contextlib.nullcontext()
#     324 )
#     326 with summon_full_params_context:
# --> 327     generated_tokens = self.model.generate(**generation_inputs, **gen_kwargs)
#     329 # Temporary hack to ensure the generation config is not initialized for each iteration of the evaluation loop
#     330 # TODO: remove this hack when the legacy code that initializes generation_config from a model config is
#     331 # removed in https://github.com/huggingface/transformers/blob/98d88b23f54e5a23e741833f1e973fdf600cc2c5/src/transformers/generation/utils.py#L1183
#     332 if self.model.generation_config._from_model_config:
#
# File c:\Users\naja\anaconda3\Lib\site-packages\torch\utils\_contextlib.py:120, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     117 @functools.wraps(func)
#     118 def decorate_context(*args, **kwargs):
#     119     with ctx_factory():
# --> 120         return func(*args, **kwargs)
#
# File c:\Users\naja\anaconda3\Lib\site-packages\transformers\generation\utils.py:2551, in GenerationMixin.generate(self, inputs, generation_config, logits_processor, stopping_criteria, prefix_allowed_tokens_fn, synced_gpus, assistant_model, streamer, negative_prompt_ids, negative_prompt_attention_mask, use_model_defaults, custom_generate, **kwargs)
#    2539     result = self._sample(
#    2540         input_ids,
#    2541         logits_processor=prepared_logits_processor,
#    (...)
#    2546         **model_kwargs,
#    2547     )
#    2549 elif generation_mode in (GenerationMode.BEAM_SAMPLE, GenerationMode.BEAM_SEARCH):
#    2550     # 11. run beam sample
# -> 2551     result = self._beam_search(
#    2552         input_ids,
#    2553         logits_processor=prepared_logits_processor,
#    2554         stopping_criteria=prepared_stopping_criteria,
#    2555         generation_config=generation_config,
#    2556         synced_gpus=synced_gpus,
#    2557         **model_kwargs,
#    2558     )
#    2560 elif generation_mode == GenerationMode.GROUP_BEAM_SEARCH:
#    2561     logger.warning_once(
#    2562         "Group Beam Search is scheduled to be moved to a `custom_generate` repository in v4.55.0. "
#    2563         "To prevent loss of backward compatibility, add `trust_remote_code=True` to your `generate` call."
#    2564     )
#
# File c:\Users\naja\anaconda3\Lib\site-packages\transformers\generation\utils.py:3366, in GenerationMixin._beam_search(self, input_ids, logits_processor, stopping_criteria, generation_config, synced_gpus, **model_kwargs)
#    3362 logits = model_outputs.logits[:, -1, :].to(copy=True, dtype=torch.float32, device=input_ids.device)
#    3364 # b. Compute log probs -- get log probabilities from logits, process logits with processors (*e.g.*
#    3365 # `temperature`, ...), and add new logprobs to existing running logprobs scores.
# -> 3366 log_probs = nn.functional.log_softmax(logits, dim=-1)
#    3367 log_probs = logits_processor(flat_running_sequences, log_probs)
#    3369 # Store logits, attentions and hidden_states when required
#
# File c:\Users\naja\anaconda3\Lib\site-packages\torch\nn\functional.py:2245, in log_softmax(input, dim, _stacklevel, dtype)
#    2243     dim = _get_softmax_dim("log_softmax", input.dim(), _stacklevel)
#    2244 if dtype is None:
# -> 2245     ret = input.log_softmax(dim)
#    2246 else:
#    2247     ret = input.log_softmax(dim, dtype=dtype)
#
# KeyboardInterrupt:

# %% [markdown]
# # Task2: Define a seq2seq transformer model using PyTorch

# %%
from tqdm import tqdm
import torch
import torch.nn as nn
import math

# %% [markdown]
# You can try to train this model; however, it requires certain GPU resources and data, and you may not be able to complete it due to resource limitations. This exercise is only meant to help you become familiar with the structure of the model. Training is not mandatory, so it's fine if you don't run the training process.

# %% [markdown]
# ### Task: Implement Positional Encoding
#
# Define a `PositionalEncoding` class in PyTorch that:
#
# - Creates sinusoidal positional encodings based on sequence length and embedding dimension.
# - Uses sine for even indices and cosine for odd indices.
# - Adds positional encodings to input embeddings during the forward pass.
# - Ensures the encoding matrix is stored as a non-trainable buffer.

# %%
class PositionalEncoding(nn.Module):
    def __init__(self, d_model, max_len=5000):
        super(PositionalEncoding, self).__init__()

        pe = torch.zeros(max_len, d_model)
        position = torch.arange(0, max_len, dtype=torch.float).unsqueeze(1)  # [max_len, 1]
        div_term = torch.exp(torch.arange(0, d_model, 2).float() * (-math.log(10000.0) / d_model))

        # 1) Apply sine to even indices
        pe[:, 0::2] = torch.sin(position * div_term)

        # 2) Apply cosine to odd indices
        pe[:, 1::2] = torch.cos(position * div_term)

        # Register as a buffer so it’s not trainable
        self.register_buffer('pe', pe.unsqueeze(0))  # [1, max_len, d_model]

    def forward(self, x):
        """
        x: [batch_size, seq_len, d_model]
        """
        seq_len = x.size(1)
        x = x + self.pe[:, :seq_len]
        return x

# %% [markdown]
# ### Task: Implement a Simple Seq2Seq Transformer
#
# Define a `SimpleSeq2SeqTransformer` class in PyTorch that:
#
# - Uses an embedding layer to convert token IDs into dense vectors.
# - Adds positional encoding to capture token order information.
# - Employs `nn.Transformer` with configurable encoder and decoder layers.
# - Applies a final linear layer to project transformer outputs to vocabulary size.
# - Implements a forward pass that encodes source inputs, decodes target inputs with a causal mask, and produces output logits

# %%
class SimpleSeq2SeqTransformer(nn.Module):

    def __init__(self, vocab_size, d_model=256, n_heads=4, n_layers=3, dropout=0.1):
        super().__init__()

        # 1) Token embedding layer
        self.embedding = nn.Embedding(vocab_size, d_model)

        # 2) Positional encoding
        self.pos_encoder = PositionalEncoding(d_model)

        # 3) Transformer module
        self.transformer = nn.Transformer(
            d_model=d_model,
            nhead=n_heads,
            num_encoder_layers=n_layers,
            num_decoder_layers=n_layers,
            batch_first=True,   # use batch_first=True for easier shape handling
            dropout=dropout
        )

        # 4) Final linear layer to project to vocab size
        self.output = nn.Linear(d_model, vocab_size)

    def forward(self, src, tgt):
        # Embed tokens and add positional encoding
        src_emb = self.embedding(src)
        tgt_emb = self.embedding(tgt)

        # Generate causal mask for target sequence
        tgt_len = tgt.size(1)
        tgt_mask = nn.Transformer.generate_square_subsequent_mask(tgt_len)

        # Transformer forward pass
        out = self.transformer(
            src=src_emb,
            tgt=tgt_emb,
            tgt_mask=tgt_mask
        )

        return self.output(out)

# %% [markdown]
# # MCQs

# %% [markdown]
# Which of the following statements about encoder–decoder (seq2seq) models is **correct**?
#
# A. The encoder always produces a single hidden vector, which is directly mapped to the final output sequence without a decoder.
#
# B. In Transformer-based seq2seq models, the decoder attends to both the previously generated tokens and the encoder’s hidden states.
#
# C. Encoder–decoder models cannot handle variable-length input or output sequences; they require fixed-length sequences on both sides.
#
# D. Attention mechanisms are only useful in the encoder and have no role in the decoder.
#
# ---
#
# **Answer: B**
#
# The decoder uses self-attention over previously generated tokens and cross-attention over the encoder’s outputs.
#
# A is wrong: classical seq2seq models don’t always collapse everything into a single vector; attention allows richer context.
#
# C is wrong: seq2seq models can handle variable-length inputs and outputs.
#
# D is wrong: attention is crucial in both encoder and decoder.
#
# ---

# %% [markdown]
# ### Question: Attention Mechanisms
#
# Which of the following statements about the **Scaled Dot-Product Attention** used in Transformers is **correct**?
#
# A. The scaling factor \( \sqrt{d_k} \) is applied to the keys before the dot product to reduce computation cost.
#
# B. Multi-head attention simply averages the outputs of multiple attention heads to improve stability.
#
# C. The softmax function in attention ensures that the attention weights over all keys for a given query sum to 1.
#
# D. Self-attention cannot capture long-range dependencies because the receptive field is limited to local context.
#
# ---
#
# **Answer: C**
#
# A is wrong: the scaling factor $\sqrt{d_k}$ is applied to the dot product, not to the keys.
#
# B is wrong: multi-head attention concatenates heads and projects, it doesn’t just average them.
#
# D is wrong: self-attention can capture long-range dependencies because every token attends to every other token.
#
# ---

# %% [markdown]
# ### Question: Attentive Encoder–Decoder Models
#
# Which of the following statements about **attentive encoder–decoder models** is correct?
#
# A. Without attention, the decoder always conditions on the entire sequence of encoder hidden states at every step.
#
# B. Attention allows the decoder to dynamically focus on different parts of the encoder’s hidden states when generating each output token.
#
# C. In attentive encoder–decoder models, attention weights are random and fixed; they are not learned during training.
#
# D. The introduction of attention prevents the decoder from using its own previously generated tokens.
#
# ---
#
# **Answer: B**
#
# A is wrong: without attention, the decoder conditions only on a fixed-size context (often the final encoder state).
#
# C is wrong: attention weights are computed dynamically during decoding.
#
# D is wrong: the decoder still uses its previously generated tokens via self-attention.
#
# ---

# %% [markdown]
# ### Question: Transformer Block
#
# Which of the following statements about a **Transformer block** (as used in the original Transformer architecture) is correct?
#
# A. Each Transformer block consists of a single feed-forward network followed by multi-head attention.
#
# B. Residual connections and layer normalization are applied around both the multi-head attention sublayer and the feed-forward sublayer.
#
# C. The position-wise feed-forward network applies the same parameters to every position, but different positions use different networks.
#
# D. In the encoder block, masked self-attention is applied to prevent attending to future tokens.
#
# ---
#
# **Answer: B**
#
# A is wrong: the block contains multi-head attention followed by feed-forward, not the other way around.
#
# C is wrong: the same parameters are applied to every position; all positions share the same feed-forward network.
#
# D is wrong: masked self-attention is only used in the decoder, not the encoder.
#
# ---

# %% [markdown]
# ### Question: Self-Attention
#
# Which of the following statements about **self-attention** in Transformers is correct?
#
# A. Self-attention computes attention weights only between different sequences in a batch, not within a single sequence.
#
# B. In self-attention, queries, keys, and values are all derived from the same input representations.
#
# C. Self-attention cannot model long-range dependencies because it only attends to local neighbors.
#
# D. The complexity of self-attention is linear in sequence length, making it more efficient than RNNs for long inputs.
#
# ---
#
# **Answer: B**
#
# A is wrong: self-attention operates within a single sequence, not between sequences in a batch.
#
# C is wrong: self-attention can model long-range dependencies.
#
# D is wrong: self-attention has quadratic complexity in sequence length, not linear.
#
# ---
